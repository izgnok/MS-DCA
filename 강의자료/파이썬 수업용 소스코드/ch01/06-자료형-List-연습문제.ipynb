# %% [markdown]
# ### 중첩 리스트 person에서 인덱싱을 사용하여 아래와 같이 출력하기

# %% [markdown]
# [ggoreb]신림동/둔산동

# %%
person = [
  'ggoreb',
  20,
  ['서울', '관악구', '신림동'],
  ['대전', '서구', '둔산동']
]

# %% [markdown]
# ###  리스트 요소 정렬하기 (오름차순, 내림차순)

# %% [markdown]
# ['h', 'n', 'o', 'p', 't', 'y']<br>
# ['y', 't', 'p', 'o', 'n', 'h']

# %%
ch_list = ['p', 'y', 't', 'h', 'o', 'n']

# %% [markdown]
# ### 곱셈 연산 과정 출력하기

# %% [markdown]
# <img src="data:image/png;base64,...">

# %% [markdown]
# (1)과 (2) 위치에 들어갈 세 자리 자연수가 주어질 때<br>
# (3), (4), (5), (6) 위치에 들어갈 값 구하기

# %%
a = 472   # (1)
b = '385' # (2)
