# %% [markdown]
# ### 두 수를 입력받은 후 덧셈 결과 출력하기

# %%
input1 = input('숫자1 입력: ')
input2 = input('숫자2 입력: ')

# 코드 작성

print('덧셈 결과:', result)

# %% [markdown]
# ### 아래와 같이 숫자들을 입력한 후 입력된 숫자들의 합 구하기
# 입력: 23, 24, 1, 9, 11, 26<br>
# 합계: 94

# %%
text = input('입력: ')
total = 0

# 코드 작성

print('합계:', total)

# %% [markdown]
# ### 반복문과 print 함수를 이용하여 아래와 같은 모습 출력하기

# %% [markdown]
# <img src="data:image/png;base64,...">

# %%
n = 5
